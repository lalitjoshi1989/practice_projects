# %% [markdown]
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# 1. Date - The date of the observation
# 2. AveragePrice - the average price of a single avocado
# 3. type - conventional or organic
# 4. year - the year
# 5. Region - the city or region of the observation
# 6. Total Volume - Total number of avocados sold
# 7. 4046 - Total number of avocados with PLU 4046 sold
# 8. 4225 - Total number of avocados with PLU 4225 sold
# 9. 4770 - Total number of avocados with PLU 4770 sold

# %%
#importing reuired libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import warnings
warnings.filterwarnings('ignore')

# %%
#importing the dataset and saving the same in a variable data and rpinting first 5 details of the dataset using head
data = pd.read_csv('avocado.csv')
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %% [markdown]
# #problem:-
# Our motto is to predict the:
#   1. Average Price (Regression)
#   2. Types of avacados (Classification)

# %%
data.shape
# Out:
# (18249, 14)

# %% [markdown]
# Our dataset consists of 18249 Rows and 14 COlumns.

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# No null values in the dataset

# %%
data.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# We can see that our dataset have 3 columns with Object Datatype and 2 columns with Integer DataType. 9 COlumns with Integer datatype

# %%
#printing all the columns in our dataset
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=45, ha='right')
sns.countplot(data["type"])
plt.show()

# %% [markdown]
# From the above graph we can say that we are having 2 types of avacado one is coventional and other is organic. They both are equally sold.

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=45, ha='right')
sns.countplot(data["region"])
plt.show()

# %% [markdown]
# We can say that all the regoin are consuming avacado similarly. As all the regio have equal count in the dataset.

# %%
#printing all the columns in our dataset
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
plt.figure(figsize =(25,8))
plt.xticks(rotation=90)
sns.lineplot(x='Date',y='AveragePrice',data=data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# From the above graph we can check that average price of the avacado had been incresed by the time.

# %%
plt.figure(figsize =(25,8))
sns.lineplot(x='AveragePrice',y='Total Volume',data=data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Total volume is the Total number of avocados sold. So, from the above graph we can say that mostly the avacados are sold at an average price of between 0.5 to 1.0 and if the average prices increases that ha,pers the sale of avacados.

# %%
plt.figure(figsize =(25,8))
sns.lineplot(x='AveragePrice',y='4046',data=data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The 4046 is the product lookup code for the hass avacado. 4046 - Total number of avocados with PLU 4046 sold.We can see that 4046 PLU avacados are sold at an avearge price of 0.5 - 1.0

# %%
plt.figure(figsize =(25,8))
sns.lineplot(x='AveragePrice',y='4225',data=data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The 4225 is the product lookup code for the hass avacado. 4225 - Total number of avocados with PLU 4225 sold. We can see that 4225 PLU avacados are sold at an avearge price of 0.5 and maximum at 1.0 and after that till 1.5

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='AveragePrice',y='4770',data=data)
plt.show()
#4770 - Total number of avocados with PLU 4770 sold

# %% [markdown]
# The 4770 is the product lookup code for the hass avacado. 4770 - Total number of avocados with PLU 4770 sold. We can see that 4770 PLU avacados are sold at an avearge price of 0.5 and maximum at 1.0 and after that till 1.5

# %%
#'Total Bags', 

plt.figure(figsize=(15,8))
sns.lineplot(x='AveragePrice',y='Total Bags',data=data)
plt.show()

# %% [markdown]
# The avacado fruit is sold in bags, though the price is for per unit. SO, we can say that total bags are sold mostly at an price of 1

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='AveragePrice',y='Small Bags',data=data)
plt.show()

# %% [markdown]
# we can say that small bags are sold mostly at an price of 1

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='AveragePrice',y='Large Bags',data=data)
plt.show()

# %% [markdown]
# we can say that large bags are sold mostly at an price of 0.5

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='AveragePrice',y='XLarge Bags',data=data)
plt.show()

# %% [markdown]
# we can say that Xlarge bags are sold mostly at an price of 1

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='AveragePrice',y='type',data=data)
plt.show()

# %% [markdown]
# From the above we can see that conventional avacados are sold mostly. The average price for the avacados lies between 0.5 to 1

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='AveragePrice',y='year',data=data)
plt.show()

# %% [markdown]
# We can see that most of the avacados are sold in 2017 at an an average price of 0.7 approx and from 2.5 to 3

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation = 90, ha ='right')
sns.lineplot(x='region',y='AveragePrice',data=data)
plt.show()

# %% [markdown]
# Above we can check the average price at which the avacados are sold in various regions. In harrisburg sranton and san francisco the avacados are sold at an average price of 1.8

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
sns.scatterplot(x='type',y='year',hue='AveragePrice',data=data)
# Out:
# <AxesSubplot:xlabel='type', ylabel='year'>

# %% [markdown]
# From the above graph we can see that, conventional avacados are sold at an average price of 0.5, however, the organic are sold at different prices.

# %%
plt.figure(figsize=(12,9))
sns.scatterplot(x='type',y='region',hue='AveragePrice',data=data)
plt.show()

# %% [markdown]
# We can say that all regions consume both the types of avacados but organic was sold at higher average price in some regions.

# %%
plt.figure(figsize=(12,9))
sns.scatterplot(x='Date',y='AveragePrice',hue='AveragePrice',data=data)
plt.show()

# %%
c=data['AveragePrice']
d=data['type']

plt.bar(c,d)
plt.title("Bar Graph")
plt.xlabel('AveragePrice')
plt.ylabel('type')
plt.show()

# %%
c=data['AveragePrice']
d=data['type']
ax=sns.stripplot(c,d)
ax.set(xlabel="Average Price",ylabel='Type')
plt.title('Avacado')
plt.show()

# %% [markdown]
# We can check that conventional avacados are sold at an average price of 2.2 and organic are sold at an average price of 3.2

# %%
c=data['AveragePrice']
d=data['Date']
plt.figure(figsize=(12,6))
ax=sns.stripplot(c,d)
ax.set(xlabel="Average Price",ylabel='Date')
plt.title('Avacado')
plt.show()

# %% [markdown]
# The above graph shows the average price at whgich the avacados are sold on various dates.

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.corr(),annot=True,fmt='.0%', cmap = 'coolwarm_r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Above is the heatmap for the avacado data:-
# 1. It states that our columns unnamed:0 is not corelated with average price or any other column.
# 2. Average Price is having bad corelation with all the columns excet they year columns wwhere we can see some positive corelation.
# 3. Also, heat map doesn't pulls the data of the object columns we are unabel to find the corelation with Date, Type and region.
# 4. Also, we can see that Total bags, small bags, large bags and XL bags are highly corelated with each other. Hence, we have multicolinearity among the dataset.

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# As we can see that Unnamed: 0 doesn't have any corelation with any independant column and Label we have dropped the column for the dataset. As it's also not contributing to the Label.

# %%
data.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# First 5 details of columns using head after removing the column.

# %%
df = data.copy()

# %% [markdown]
# We have copied the dataset to another dataframe usiung copy function.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Date'] = le.fit_transform(df['Date'])
df['type'] = le.fit_transform(df['type'])
df['region'] = le.fit_transform(df['region'])

# %% [markdown]
# We have converted the columns Date, type, regon with object datatype to numerical using label encoder.

# %%
df.head()
# Out:
#    Date  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0    51          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1    50          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2    49          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3    48          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4    47          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region
# 0     8603.62       93.25          0.0     0  2015       0
# 1     9408.07       97.49          0.0     0  2015       0
# 2     8042.21      103.14          0.0     0  2015       0
# 3     5677.40      133.76          0.0     0  2015       0
# 4     5986.26      197.69          0.0     0  2015       0

# %%
df['Date_new'] = df['Date']
df.drop('Date',axis=1,inplace=True)
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Date_new
# 0     8603.62       93.25          0.0     0  2015       0        51
# 1     9408.07       97.49          0.0     0  2015       0        50
# 2     8042.21      103.14          0.0     0  2015       0        49
# 3     5677.40      133.76          0.0     0  2015       0        48
# 4     5986.26      197.69          0.0     0  2015       0        47

# %%
df.plot(kind='box',subplots=True, layout=(5,7), figsize = (15,13))
# Out:
# AveragePrice       AxesSubplot(0.125,0.749828;0.0945122x0.130172)
# Total Volume    AxesSubplot(0.238415,0.749828;0.0945122x0.130172)
# 4046            AxesSubplot(0.351829,0.749828;0.0945122x0.130172)
# 4225            AxesSubplot(0.465244,0.749828;0.0945122x0.130172)
# 4770            AxesSubplot(0.578659,0.749828;0.0945122x0.130172)
# Total Bags      AxesSubplot(0.692073,0.749828;0.0945122x0.130172)
# Small Bags      AxesSubplot(0.805488,0.749828;0.0945122x0.130172)
# Large Bags         AxesSubplot(0.125,0.593621;0.0945122x0.130172)
# XLarge Bags     AxesSubplot(0.238415,0.593621;0.0945122x0.130172)
# type            AxesSubplot(0.351829,0.593621;0.0945122x0.130172)
# year            AxesSubplot(0.465244,0.593621;0.0945122x0.130172)
# region          AxesSubplot(0.578659,0.593621;0.0945122x0.130172)
# Date_new        AxesSubplot(0.692073,0.593621;0.0945122x0.130172)
# dtype: object

# %% [markdown]
# We have plotted a box plot to check wether the dataset contains outliers or not. We can see that columns:-
# 1. Average Price
# 2. Total volume
# 3. 4046
# 4. 4225
# 5. 4770
# 6. Totla Bags
# 7. Small Bags
# 8. Large Bags
# 9. Xlarge bags
#
# Contains Outliers.

# %%
from scipy.stats import zscore

# %%
zscore = np.abs(zscore(df))

threshold = 3
print(np.where(zscore>3))

df_new = df[(zscore<3).all(axis=1)]
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
print("Shape of dataset before removing outliers :",df.shape)
print("Shape of dataset after removing outliers :",df_new.shape)
# Out:
# Shape of dataset before removing outliers : (18249, 13)
# Shape of dataset after removing outliers : (17651, 13)

# %%
data_loss = (18249-17651)/18249*100
data_loss
# Out:
# 3.276891884486821

# %% [markdown]
# We called zscore method to remove outliers from the dataset. We successfully removed the outliers and we can check that 3 rows were removed from gthe dataset and we have a 3% data loss, which we can accept.

# %%
df_new.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# Date_new        0.013714
# dtype: float64

# %% [markdown]
# We have used skew function to check if the dataset is having skewness and we can see that our columns:-
#    1. Total Volume
#    2. 4046
#    3. 4225
#    4. 4770
#    5. Total Bags
#    6. Small Bags
#    7. Large bags
#    8. XL bags, are highly skewed.

# %%
col2 = df_new.columns
for i in col2:
    if (df_new[i].skew() > 0.55 or df_new[i].skew() < -0.55): 
        print(i)
# Out:
# Total Volume
# 4046
# 4225
# 4770
# Total Bags
# Small Bags
# Large Bags
# XLarge Bags

# %% [markdown]
# The above columns in our dataset are havig high skewness.

# %%
for col in df_new:
    print(col)
    print(df_new[col].skew())
    if (df_new[col].skew() > 0.55 or df_new[col].skew() < -0.55): 
        print("Column is having skewness")
    else:
        print("No skewness is present")
    
    plt.figure()
    sns.distplot(df_new[col])
    plt.show()
# Out:
# AveragePrice
# 0.37743186924132965
# No skewness is present
# Total Volume
# 3.767137602983901
# Column is having skewness
# 4046
# 4.909847799473674
# Column is having skewness
# 4225
# 4.455745349647941
# Column is having skewness
# 4770
# 5.117169679810346
# Column is having skewness
# Total Bags
# 4.06677130442822
# Column is having skewness
# Small Bags
# 4.222705587481023
# Column is having skewness
# Large Bags
# 5.0534342348618075
# Column is having skewness
# XLarge Bags
# 6.135607410296316
# Column is having skewness
# type
# -0.03774149713284268
# No skewness is present
# year
# 0.22997611486338987
# No skewness is present
# region
# 0.012797890588826565
# No skewness is present
# Date_new
# 0.013713816874353729
# No skewness is present

# %% [raw]
# for col in df_new:
#     print(col)
#     print(df_new[col].skew())
#     if (df_new[col].skew() > 0.55 or df_new[col].skew() < -0.55):
#         print("Graph before removing skewness", sns.distplot(df_new[col]))
#         print('---------------------------------------------------------------------------------')
#         df_new[col] = np.log(df_new[col])
#         print("value after removing the skewness", df_new[col].skew())
#         print("New graph :-",sns.distplot(df_new[col]))

# %%
#Total Volume
#4046
#4225
#4770
#Total Bags
#Small Bags
#Large Bags
#XLarge Bags

df_new['Total Volume'] = np.sqrt(df_new['Total Volume'])
df_new['4046'] = np.sqrt(df_new['4046'])
df_new['4046'] = np.sqrt(df_new['4046'])
df_new['4225'] = np.sqrt(df_new['4225'])
df_new['Total Bags'] = np.sqrt(df_new['Total Bags'])
df_new['Small Bags'] = np.sqrt(df_new['Small Bags'])
df_new['Large Bags'] = np.sqrt(df_new['Large Bags'])
df_new['XLarge Bags'] = np.sqrt(df_new['XLarge Bags'])

# %%
df_new.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    1.963864
# 4046            1.082068
# 4225            2.128505
# 4770            5.117170
# Total Bags      2.010691
# Small Bags      2.093752
# Large Bags      2.236756
# XLarge Bags     3.312484
# type           -0.037741
# year            0.229976
# region          0.012798
# Date_new        0.013714
# dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True,fmt='.0%', cmap = 'coolwarm_r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Now as we have successfully converted our data to numerical format and reconstructed the heatmap to check corelation among the label and inputs.
# 1. from the above data we can see that our label is highly corelated with the type and having good corelation with the date.
# 2. we can see that all the input variables are having good corelation with each other as we can check that in section above covered in blue. Our dataset is having high multicolinearity.
# 3. Eg: VOlume is having good relation with all the columns except: - type and average price.

# %%
df.shape
# Out:
# (18249, 13)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(x):
    vif = pd.DataFrame()
    vif["Variables"] = x.columns
    vif["VIF Factor"] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1]) ]
    return (vif)

# %%
calc_vif(df_new)
# Out:
#        Variables  VIF Factor
# 0   AveragePrice   27.837920
# 1   Total Volume  142.585601
# 2           4046   35.864520
# 3           4225   33.421434
# 4           4770    2.250912
# 5     Total Bags  480.164862
# 6     Small Bags  293.345336
# 7     Large Bags   30.032622
# 8    XLarge Bags    2.415042
# 9           type    5.971198
# 10          year   39.732437
# 11        region    4.382558
# 12      Date_new    5.039826

# %% [markdown]
# As we have seen through heatmap that our dataset having multicolinearity. Calculating the same using the VIF factor and checking the columns having multicolinearity.

# %% [markdown]
# df_new.drop('Total Volume',axis=1,inplace=True)
# df_new.drop('4046',axis=1,inplace=True)
# df_new.drop('4225',axis=1,inplace=True)
# df_new.drop('Total Bags',axis=1,inplace=True)
# df_new.drop('Small Bags',axis=1,inplace=True)
# df_new.drop('Large Bags',axis=1,inplace=True)
# df_new.drop('year',axis=1,inplace=True)

# %%
df_new.head()
# Out:
#    AveragePrice  Total Volume      4046        4225    4770  Total Bags  \
# 0          1.33    253.449443  5.674368  233.355630   48.16   93.257010
# 1          1.35    234.258362  5.095773  211.278986   58.33   97.496461
# 2          0.93    343.831674  5.309466  330.378071  130.50   90.251593
# 3          1.08    281.055422  5.800449  268.284196   72.58   76.230965
# 4          1.28    225.919455  5.539273  209.376193   75.78   78.638095
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Date_new
# 0   92.755701    9.656604          0.0     0  2015       0        51
# 1   96.995206    9.873702          0.0     0  2015       0        50
# 2   89.678370   10.155787          0.0     0  2015       0        49
# 3   75.348524   11.565466          0.0     0  2015       0        48
# 4   77.370925   14.060228          0.0     0  2015       0        47

# %%
df_new.shape
# Out:
# (17651, 13)

# %%
x = df_new.iloc[:,1:13]
x.head()
# Out:
#    Total Volume      4046        4225    4770  Total Bags  Small Bags  \
# 0    253.449443  5.674368  233.355630   48.16   93.257010   92.755701
# 1    234.258362  5.095773  211.278986   58.33   97.496461   96.995206
# 2    343.831674  5.309466  330.378071  130.50   90.251593   89.678370
# 3    281.055422  5.800449  268.284196   72.58   76.230965   75.348524
# 4    225.919455  5.539273  209.376193   75.78   78.638095   77.370925
#
#    Large Bags  XLarge Bags  type  year  region  Date_new
# 0    9.656604          0.0     0  2015       0        51
# 1    9.873702          0.0     0  2015       0        50
# 2   10.155787          0.0     0  2015       0        49
# 3   11.565466          0.0     0  2015       0        48
# 4   14.060228          0.0     0  2015       0        47

# %%
y= df_new.iloc[:,0]
y.head()
# Out:
# 0    1.33
# 1    1.35
# 2    0.93
# 3    1.08
# 4    1.28
# Name: AveragePrice, dtype: float64

# %% [markdown]
# From line 53 - 57:
#  1. We checked the head first 5 rows and columns values of our datset
#  2. CHecked shape of the dataset.
#  3. Splitted the dataset. X contains all independant variables and y contains the target variable or Label.

# %% [markdown]
# from sklearn.decomposition import PCA
# pca = PCA(n_components = 5)
# x=pd.DataFrame(pca.fit_transform(x))

# %% [markdown]
# We have now using PCA- pricipal component analysis to treat the multicolinearity of independant variables in our dataset.

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')

# %% [markdown]
# We observed that abive method didn't remove the skewness completely so ,We have now removed the skewness using yeo-johnson method

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
lr = LinearRegression()
dtc = DecisionTreeRegressor()
svc = SVR()
rnd = RandomForestRegressor()

# %%
best_state = []
for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30, random_state = i)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,1) == round(r2_score(y_test,pred_test)*100,1):
        print("AT random state",i,"the model performing good")
        best_state.append(i)
# Out:
# AT random state 4 the model performing good
# AT random state 8 the model performing good
# AT random state 18 the model performing good
# AT random state 31 the model performing good
# AT random state 32 the model performing good
# AT random state 40 the model performing good
# AT random state 51 the model performing good

# %%
best_state
# Out:
# [4, 8, 18, 31, 32, 40, 51]

# %%
for i in best_state:
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30, random_state = i)
    lr.fit(x_train,y_train)
    pred_lr = lr.predict(x_test)
    print('Error Calculations for Linear Regression at:-',i,"is")
    print('Means absolute error', mean_absolute_error(y_test,pred_lr))
    print('Means Squared Error',mean_squared_error(y_test,pred_lr))
    print('Root mean square', np.sqrt(mean_squared_error(y_test,pred_lr)))
    print('Model Score',r2_score(y_test,pred_lr))
    print("---------------------------------------------------")
# Out:
# Error Calculations for Linear Regression at:- 4 is
# Means absolute error 0.20353232715036507
# Means Squared Error 0.06594226758103174
# Root mean square 0.2567922654229129
# Model Score 0.5510917779923612
# ---------------------------------------------------
# Error Calculations for Linear Regression at:- 8 is
# Means absolute error 0.20624541998089616
# Means Squared Error 0.06845013396695113
# Root mean square 0.2616297650630584
# Model Score 0.5506393394597864
# ---------------------------------------------------
# Error Calculations for Linear Regression at:- 18 is
# Means absolute error 0.20567679305850167
# Means Squared Error 0.06727279264472517
# Root mean square 0.2593699917969023
# Model Score 0.5505424755553352
# ---------------------------------------------------
# Error Calculations for Linear Regression at:- 31 is
# Means absolute error 0.20520342421193963
# Means Squared Error 0.06788013734630347
# Root mean square 0.2605381686937702
# Model Score 0.5506963916501076
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30, random_state = 50)
svc.fit(x_train,y_train)
pred_svc = svc.predict(x_test)
print('Means absolute error', mean_absolute_error(y_test,pred_svc))
print('Means Squared Error',mean_squared_error(y_test,pred_svc))
print('Root mean square', np.sqrt(mean_squared_error(y_test,pred_svc)))
print('Model Score',r2_score(y_test,pred_svc))
print("---------------------------------------------------")
# Out:
# Means absolute error 0.13997881110578592
# Means Squared Error 0.034943829349308474
# Root mean square 0.18693268667974702
# Model Score 0.763248338848503
# ---------------------------------------------------

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30, random_state = 50)
dtc.fit(x_train,y_train)
pred_dtc = dtc.predict(x_test)
print('Error Calculations for')
print('Means absolute error', mean_absolute_error(y_test,pred_dtc))
print('Means Squared Error',mean_squared_error(y_test,pred_dtc))
print('Root mean square', np.sqrt(mean_squared_error(y_test,pred_dtc)))
print('Model Score',r2_score(y_test,pred_dtc))
print("---------------------------------------------------")
# Out:
# Error Calculations for
# Means absolute error 0.12054758308157101
# Means Squared Error 0.033442711480362534
# Root mean square 0.18287348490243885
# Model Score 0.7734187224519868
# ---------------------------------------------------

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30, random_state = 50)
rnd.fit(x_train,y_train)
pred_rnd = rnd.predict(x_test)

print('Error Calculations: -')

print('Means absolute error', mean_absolute_error(y_test,pred_rnd))
print('Means Squared Error',mean_squared_error(y_test,pred_rnd))
print('Root mean square', np.sqrt(mean_squared_error(y_test,pred_rnd)))
print('Model Score',r2_score(y_test,pred_rnd))
# Out:
# Error Calculations: -
# Means absolute error 0.08704694108761328
# Means Squared Error 0.015003215536253769
# Root mean square 0.1224876138074939
# Model Score 0.8983501159728414

# %% [markdown]
# From code line 89 - 97 :
# 1. We called the train and test split from sklearn so that we could split the data for training and testing purpose.
# 2. Called all the algorithms that I am going to use to predict the model.
# 3. Passed the train and test data to variuos algorithms and found that RandomForestRegressor is giving the best result that is 84.
#
# Hence we can say that RandomForestRegressor is the best algorithms for the dataset to predict the model.

# %% [raw]
# from sklearn.model_selection import GridSearchCV
# parameters = { 'n_estimators' :[200,300,400,500],
#                'criterion'  :['squared_error','mse','absolute_error','poisson'],
#                'max_depth' :[10,20,30,40,50],
#                'min_samples_split' :[10,20,30,40,50]
#              }
#
# grid_cv = GridSearchCV(estimator=rnd, param_grid = parameters)
# grid_cv.fit(x_test, y_test)
# best_para = grid_cv.best_params_
# print(best_para)
# best_result = grid_cv.best_score_
# print(best_result)
# print(round(best_result,2))

# %% [markdown]
# Performing hyper parameter tuning to check best parametrs and find best scores for the dataset.

# %%
from sklearn.model_selection import cross_val_score
score_dtc=cross_val_score(dtc,x,y,cv=5)
print('\n')
print(score_dtc)
print(score_dtc.mean())
print(score_dtc.std())
print('------------------------')
score_lr=cross_val_score(lr,x,y,cv=5)
print(score_lr)
print(score_lr.mean())
print(score_lr.std())
print('------------------------')
score_svc=cross_val_score(svc,x,y,cv=5)
print(score_svc)
print(score_svc.mean())
print(score_svc.std())
print('------------------------')
score_rnd=cross_val_score(rnd,x,y,cv=5)
print(score_rnd)
print(score_rnd.mean())
print(score_rnd.std())
print('------------------------')
# Out:
# [-0.31261884  0.11079174  0.22780571 -0.18592591 -0.32724765]
# -0.09743899123967734
# 0.22631327002492962
# ------------------------
# [-0.20678133  0.17897943  0.44021301  0.21946494  0.28015713]
# 0.18240663495614867
# 0.2139493514565781
# ------------------------
# [-0.31812078  0.51639646  0.33928593  0.38779098  0.28704352]
# 0.24247922127630744
# 0.29043968135869686
# ------------------------
# [0.45434818 0.58360352 0.65085386 0.42540392 0.11147515]
# 0.44513692740697597
# 0.18617028334828448
# ------------------------

# %% [markdown]
# Calculating CV score for the algorithms

# %%
print('Model Score',r2_score(y_test,pred_dtc))
print('Mean Score After CV',score_dtc.mean())
print("Model Score is", r2_score(y_test,pred_dtc)-score_dtc.mean())
print('\n')      
      
print('Model Score',r2_score(y_test,pred_lr))
print('Mean Score After CV',score_lr.mean())
print("Model Score is", r2_score(y_test,pred_lr)-score_lr.mean())
print('\n')      
      
print('Model Score',r2_score(y_test,pred_svc))
print('Mean Score After CV',score_svc.mean())
print("Model Score is", r2_score(y_test,pred_svc)-score_svc.mean())
print('\n')      
      
print('Model Score',r2_score(y_test,pred_rnd))
print('Mean Score After CV',score_rnd.mean())
print("Model Score is", r2_score(y_test,pred_rnd)-score_rnd.mean())
# Out:
# Model Score 0.7734187224519868
# Mean Score After CV -0.09743899123967734
# Model Score is 0.8708577136916642
#
#
# Model Score -0.6261107299232123
# Mean Score After CV 0.18240663495614867
# Model Score is -0.8085173648793609
#
#
# Model Score 0.763248338848503
# Mean Score After CV 0.24247922127630744
# Model Score is 0.5207691175721956
#
#
# Model Score 0.8983501159728414
# Mean Score After CV 0.44513692740697597
# Model Score is 0.45321318856586545

# %% [markdown]
# We have calculated the difference between the CV mean score and algo score, we can see that Random forest has the least difference hence we can say that Random forest is the best algorith for our model.

# %% [raw]
# import pickle
# filename = 'avacado_regression_final_model.pkl'
# pickle.dump(rnd, open(filename, 'wb'))

# %%
df_class = data.copy()
df_class.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# Loaded the dataset for next classification model.

# %%
df_class['Date'] = le.fit_transform(df_class['Date'])
df_class['type'] = le.fit_transform(df_class['type'])
df_class['region'] = le.fit_transform(df_class['region'])

# %% [markdown]
# We had few columns that are in object form so we have converted them in numerica form which is required by Machine learning.

# %%
df_class.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df_class.shape
# Out:
# (18249, 13)

# %%
df_class.plot(kind='box', subplots=True, layout = (5,7), figsize = (15,13))
# Out:
# Date               AxesSubplot(0.125,0.749828;0.0945122x0.130172)
# AveragePrice    AxesSubplot(0.238415,0.749828;0.0945122x0.130172)
# Total Volume    AxesSubplot(0.351829,0.749828;0.0945122x0.130172)
# 4046            AxesSubplot(0.465244,0.749828;0.0945122x0.130172)
# 4225            AxesSubplot(0.578659,0.749828;0.0945122x0.130172)
# 4770            AxesSubplot(0.692073,0.749828;0.0945122x0.130172)
# Total Bags      AxesSubplot(0.805488,0.749828;0.0945122x0.130172)
# Small Bags         AxesSubplot(0.125,0.593621;0.0945122x0.130172)
# Large Bags      AxesSubplot(0.238415,0.593621;0.0945122x0.130172)
# XLarge Bags     AxesSubplot(0.351829,0.593621;0.0945122x0.130172)
# type            AxesSubplot(0.465244,0.593621;0.0945122x0.130172)
# year            AxesSubplot(0.578659,0.593621;0.0945122x0.130172)
# region          AxesSubplot(0.692073,0.593621;0.0945122x0.130172)
# dtype: object

# %% [markdown]
# From the above graph we can see that we have a lot of outliers in various columns. Will use zscore method to re,ove outliers.

# %%
from scipy.stats import zscore
zscore = np.abs(zscore(df_class))

threshold = 3
print(np.where(zscore>3))

df_class_new = df_class[(zscore<3).all(axis=1)]
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([3, 3, 9, ..., 1, 1, 1], dtype=int64))

# %%
print("Shape of dataset before removing outliers :",df_class.shape)
print("Shape of dataset after removing outliers :",df_class_new.shape)
#calculating the data loss
data_loss = (18249-17651)/18249*100
data_loss
# Out:
# Shape of dataset before removing outliers : (18249, 13)
# Shape of dataset after removing outliers : (17651, 13)
# 3.276891884486821

# %% [markdown]
# We called zscore to remove outliers and then calculated the data loss which we can see is 3 which is good to go

# %%
df_class_new.skew()
# Out:
# Date            0.013714
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# dtype: float64

# %% [markdown]
# We can check that the data is skewed

# %%
for col in df_class_new:
    print(col)
    print(df_class_new[col].skew())
    if (df_class_new[col].skew() > 0.55 or df_class_new[col].skew() < -0.55): 
        print("Column is having skewness")
    else:
        print("No skewness is present")
    
    plt.figure()
    sns.distplot(df_class_new[col])
    plt.show()
# Out:
# Date
# 0.013713816874353729
# No skewness is present
# AveragePrice
# 0.37743186924132965
# No skewness is present
# Total Volume
# 3.767137602983901
# Column is having skewness
# 4046
# 4.909847799473674
# Column is having skewness
# 4225
# 4.455745349647941
# Column is having skewness
# 4770
# 5.117169679810346
# Column is having skewness
# Total Bags
# 4.06677130442822
# Column is having skewness
# Small Bags
# 4.222705587481023
# Column is having skewness
# Large Bags
# 5.0534342348618075
# Column is having skewness
# XLarge Bags
# 6.135607410296316
# Column is having skewness
# type
# -0.03774149713284268
# No skewness is present
# year
# 0.22997611486338987
# No skewness is present
# region
# 0.012797890588826565
# No skewness is present

# %% [markdown]
# The above is the graphical representation of the skewness present in the dataset

# %%
df_class_new.head()
# Out:
#    Date  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0    51          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1    50          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2    49          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3    48          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4    47          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region
# 0     8603.62       93.25          0.0     0  2015       0
# 1     9408.07       97.49          0.0     0  2015       0
# 2     8042.21      103.14          0.0     0  2015       0
# 3     5677.40      133.76          0.0     0  2015       0
# 4     5986.26      197.69          0.0     0  2015       0

# %%
x = df_class_new.iloc[:,1:12]
x.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year
# 0     8603.62       93.25          0.0     0  2015
# 1     9408.07       97.49          0.0     0  2015
# 2     8042.21      103.14          0.0     0  2015
# 3     5677.40      133.76          0.0     0  2015
# 4     5986.26      197.69          0.0     0  2015

# %%
x.shape
# Out:
# (17651, 11)

# %%
y = df_class_new['region']
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: region, dtype: int32

# %%
y.shape
# Out:
# (17651,)

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')

# %% [markdown]
# We have removed the skewness using yeo-johnson

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lrc = LogisticRegression()
gnbc = GaussianNB()
svcc = SVC()
knnc = KNeighborsClassifier()
dtcc = DecisionTreeClassifier()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30, random_state = 50)

# %%
print(lrc.fit(x_train,y_train))
print(gnbc.fit(x_train,y_train))
print(svcc.fit(x_train,y_train))
print(knnc.fit(x_train,y_train))
print(dtcc.fit(x_train,y_train))
# Out:
# LogisticRegression()
# GaussianNB()
# SVC()
# KNeighborsClassifier()
# DecisionTreeClassifier()

# %%
pred_lr = lrc.predict(x_test)
pred_gnb = gnbc.predict(x_test)
pred_svc = svcc.predict(x_test)
pred_knn = knnc.predict(x_test)
pred_dtc = dtcc.predict(x_test)

# %%
print("Printing the Accuracy Score, Confusion Matrix and Classification Report for our model:- ")

print("Details for Linear Regression Model :-")
print(accuracy_score(y_test,pred_lr),'\n')
print(confusion_matrix(y_test,pred_lr),'\n')
print(classification_report(y_test,pred_lr),'\n')

print("Details for Naive Bayes Model :-")
print(accuracy_score(y_test,pred_gnb),'\n')
print(confusion_matrix(y_test,pred_gnb),'\n')
print(classification_report(y_test,pred_gnb),'\n')

print("Details for Support Vector Model :-")
print(accuracy_score(y_test,pred_svc),'\n')
print(confusion_matrix(y_test,pred_svc),'\n')
print(classification_report(y_test,pred_svc),'\n')

print("Details for KNN Model :-")
print(accuracy_score(y_test,pred_knn),'\n')
print(confusion_matrix(y_test,pred_knn),'\n')
print(classification_report(y_test,pred_knn),'\n')

print("Details for Decision Tree :-")
print(accuracy_score(y_test,pred_dtc),'\n')
print(confusion_matrix(y_test,pred_dtc),'\n')
print(classification_report(y_test,pred_dtc),'\n')
# Out:
# Printing the Accuracy Score, Confusion Matrix and Classification Report for our model:-
# Details for Linear Regression Model :-
# 0.550226586102719
#
# [[52  0  0 ...  0  0  0]
#  [ 0 42  0 ...  0  0  0]
#  [ 0  0 61 ...  0  0  5]
#  ...
#  [ 0  0  0 ... 60  1  0]
#  [ 0  0  0 ...  0 63  0]
#  [ 0  3  2 ...  0  0 18]]
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57       103
#            1       0.24      0.41      0.31       102
#            2       0.64      0.66      0.65        93
#            3       0.61      0.44      0.51        95
#            4       0.55      0.53      0.54       106
#            5       0.57      0.62      0.60        90
#            6       0.85      0.90      0.87        92
#            7       0.62      0.64      0.63       102
#            8       0.69      0.81      0.75       105
#            9       0.56      0.73      0.64        96
#           10       0.58      0.50      0.54       103
# ...

# %% [markdown]
# As we can see that KNN is giving high result we can change some parameteres and see if the results get better

# %% [markdown]
# class sklearn.neighbors.KNeighborsClassifier(n_neighbors=5, *, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=None)

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(lrc,x,y,cv=5)
print('\n')
print(score)
print(score.mean())
print(score.std())
print('------------------------')
score=cross_val_score(gnbc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
print('------------------------')
score=cross_val_score(svcc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
print('------------------------')
score=cross_val_score(knnc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
print('------------------------')
score=cross_val_score(dtcc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.34097989 0.39773371 0.46713881 0.4733711  0.31756374]
# 0.399357451564171
# 0.06351869134153296
# ------------------------
# [0.04078165 0.03172805 0.04447592 0.05070822 0.03569405]
# 0.04067757611058027
# 0.006632972167239618
# ------------------------
# [0.62928349 0.71388102 0.70708215 0.65609065 0.48498584]
# 0.638264629830646
# 0.0828812483010177
# ------------------------
# [0.59728122 0.54192635 0.62946176 0.53909348 0.42606232]
# 0.5467650265595779
# 0.06934269005734003
# ------------------------
# [0.47635231 0.68356941 0.63087819 0.55382436 0.42691218]
# 0.5543072888210692
# 0.09474019505989985

# %%
from sklearn.model_selection import GridSearchCV

parameter = [{'n_neighbors':[5,10,15,20] , 'weights' : ['uniform'], 'algorithm' : ['auto']},
            {'n_neighbors':[10,20,30,40] , 'weights' : ['distance'], 'algorithm' : ['ball_tree'], 'leaf_size':[40]},
            {'n_neighbors':[2,4,6,8,10] , 'weights' : ['uniform'], 'algorithm' : ['kd_tree']},
            {'n_neighbors':[10,20,30,40],'weights':['distance'],'algorithm':['ball_tree'],'leaf_size':[40],'p':[2],'metric':['minkowski'],'n_jobs':[-1]}]

grid_search = GridSearchCV ( estimator = knnc,
                            param_grid = parameter,
                            scoring = 'accuracy',
                            cv = 10,
                            n_jobs = -1)
grid_search = grid_search.fit(x_train,y_train)

# %%
accuracy = grid_search.best_score_
accuracy
# Out:
# 0.8425753049539457

# %%
grid_search.best_params_
# Out:
# {'algorithm': 'kd_tree', 'n_neighbors': 2, 'weights': 'uniform'}

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
y_predict_prob = knnc.predict_proba(x_test)[:,1]

# %%
fpr,tpr,threshold = roc_curve(y_test,y_predict_prob)

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='KNN Classifier')
plt.xlabel('False')
plt.ylabel('True')
plt.title('KNN Classifier')
plt.show()

# %%
import pickle
filename = 'avacado_classiffication.pkl'
pickle.dump(knnc, open(filename, 'wb'))
