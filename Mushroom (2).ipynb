# %% [markdown]
# Importing libraries required to read the csv file of the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %% [markdown]
# Checking the shape of our dataset. We can check that our dataset is having 8124 Rows and 23 Columns.

# %% [markdown]
# Dataset Contains non numeric values and we need to use label encoder to convert the data.

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# Dataset doesn't have any null values.

# %% [markdown]
# Coverting the dataset to numerical values using encoder.

# %%
sns.countplot(df['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_new = df.apply(le.fit_transform)
df_new
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %% [markdown]
# We have now coverted the string inputs to numerical and we can check that the Class Column(Labels are coverted to 0 and 1) where 0 is poisnous and 1 is Edible one.

# %% [markdown]
# Checking all the columns in the dataset:-

# %%
column = df_new.columns
column
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df_new.plot(kind='box', subplots=True, layout=(4,7), figsize = (15,13))
# Out:
# class                           AxesSubplot(0.125,0.71587;0.0945122x0.16413)
# cap-shape                    AxesSubplot(0.238415,0.71587;0.0945122x0.16413)
# cap-surface                  AxesSubplot(0.351829,0.71587;0.0945122x0.16413)
# cap-color                    AxesSubplot(0.465244,0.71587;0.0945122x0.16413)
# bruises                      AxesSubplot(0.578659,0.71587;0.0945122x0.16413)
# odor                         AxesSubplot(0.692073,0.71587;0.0945122x0.16413)
# gill-attachment              AxesSubplot(0.805488,0.71587;0.0945122x0.16413)
# gill-spacing                   AxesSubplot(0.125,0.518913;0.0945122x0.16413)
# gill-size                   AxesSubplot(0.238415,0.518913;0.0945122x0.16413)
# gill-color                  AxesSubplot(0.351829,0.518913;0.0945122x0.16413)
# stalk-shape                 AxesSubplot(0.465244,0.518913;0.0945122x0.16413)
# stalk-root                  AxesSubplot(0.578659,0.518913;0.0945122x0.16413)
# ...

# %% [markdown]
# From the above graphs we can check that outliers are present in the dataset in population, habitat, ring number, veil color, stalk color below ring, stalk color above ring, stalk root, gill spacing and gill attachment.

# %% [markdown]
# Checking Skewness

# %%
df_new.skew()
# Out:
# class                       0.071946
# cap-shape                  -0.247052
# cap-surface                -0.590859
# cap-color                   0.706965
# bruises                     0.342750
# odor                       -0.080790
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                  0.061410
# stalk-shape                -0.271345
# stalk-root                  0.947852
# stalk-surface-above-ring   -1.098739
# stalk-surface-below-ring   -0.757703
# stalk-color-above-ring     -1.835434
# stalk-color-below-ring     -1.791593
# veil-type                   0.000000
# veil-color                 -6.946944
# ring-number                 2.701657
# ring-type                  -0.290018
# spore-print-color           0.548426
# population                 -1.413096
# habitat                     0.985548
# dtype: float64

# %% [markdown]
# From the above information we can check that gill-attachment, stalk-surface-above-ring, stalk-color-above-ring, stalk-color-below-ring and veil color have skewness.

# %%
sns.distplot(df_new['gill-attachment'])
# Out:
# <AxesSubplot:xlabel='gill-attachment', ylabel='Density'>

# %%
sns.distplot(df_new['stalk-surface-above-ring'])
# Out:
# <AxesSubplot:xlabel='stalk-surface-above-ring', ylabel='Density'>

# %%
sns.distplot(df_new['stalk-color-above-ring'])
# Out:
# <AxesSubplot:xlabel='stalk-color-above-ring', ylabel='Density'>

# %%
sns.distplot(df_new['stalk-color-below-ring'])
# Out:
# <AxesSubplot:xlabel='stalk-color-below-ring', ylabel='Density'>

# %%
sns.distplot(df_new['veil-color'])
# Out:
# <AxesSubplot:xlabel='veil-color', ylabel='Density'>

# %%
sns.distplot(df_new['population'])
# Out:
# <AxesSubplot:xlabel='population', ylabel='Density'>

# %% [markdown]
# The above graphs shows that the skewness in different columns

# %% [markdown]
# checking corelation between data

# %%
df_new.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
x = df_new.iloc[:,1:23]
x
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
y = df_new['class']
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=30,test_size=.30)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predict = dt.predict(x_test)

# %%
print(accuracy_score(y_test,predict))
# Out:
# 1.0

# %%
print(confusion_matrix(y_test,predict))
# Out:
# [[1304    0]
#  [   0 1134]]

# %%
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1304
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predict_lg = lg.predict(x_test)

# %%
print(accuracy_score(y_test,predict_lg))
# Out:
# 0.9561115668580804

# %%
print(confusion_matrix(y_test,predict_lg))
# Out:
# [[1258   46]
#  [  61 1073]]

# %%
print(classification_report(y_test,predict_lg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      1304
#            1       0.96      0.95      0.95      1134
#
#     accuracy                           0.96      2438
#    macro avg       0.96      0.96      0.96      2438
# weighted avg       0.96      0.96      0.96      2438

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
naive = MultinomialNB()

# %%
naive.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
predict_naive = naive.predict(x_test)

# %%
print(accuracy_score(y_test,predict_naive))
# Out:
# 0.8158326497128794

# %%
print(confusion_matrix(y_test,predict_naive))
# Out:
# [[1242   62]
#  [ 387  747]]

# %%
print(classification_report(y_test,predict_naive))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      1304
#            1       0.92      0.66      0.77      1134
#
#     accuracy                           0.82      2438
#    macro avg       0.84      0.81      0.81      2438
# weighted avg       0.84      0.82      0.81      2438

# %%
from sklearn.svm import SVC

# %%
sup_vect = SVC()

# %%
sup_vect.fit(x_train,y_train)
# Out:
# SVC()

# %%
predict_sup_vect = sup_vect.predict(x_test)

# %%
print(accuracy_score(y_test,predict_sup_vect))
print('\n')
print(confusion_matrix(y_test,predict_sup_vect))
print('\n')
print(classification_report(y_test,predict_sup_vect))
# Out:
# 0.9897456931911403
#
#
# [[1298    6]
#  [  19 1115]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1304
#            1       0.99      0.98      0.99      1134
#
#     accuracy                           0.99      2438
#    macro avg       0.99      0.99      0.99      2438
# weighted avg       0.99      0.99      0.99      2438

# %%
from sklearn.svm import SVC

# %%
svm = SVC(kernel = 'linear', degree = 5 , max_iter = 2)

svm.fit(x_train,y_train)

predict_svm = svm.predict(x_test)

print(accuracy_score(y_test,predict_svm))
print('\n')
print(confusion_matrix(y_test,predict_svm))
print('\n')
print(classification_report(y_test,predict_svm))
# Out:
# 0.5762920426579163
#
#
# [[ 346  958]
#  [  75 1059]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.27      0.40      1304
#            1       0.53      0.93      0.67      1134
#
#     accuracy                           0.58      2438
#    macro avg       0.67      0.60      0.54      2438
# weighted avg       0.68      0.58      0.53      2438

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dc = DecisionTreeRegressor(min_samples_split = 5, splitter = "random")
dc
# Out:
# DecisionTreeRegressor(min_samples_split=5, splitter='random')

# %%
dc.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(min_samples_split=5, splitter='random')

# %%
predict_dc = dc.predict(x_test)
predict_dc
# Out:
# array([0., 0., 0., ..., 1., 1., 0.])

# %%
print(accuracy_score(y_test,predict_dc))
print('\n')
print(confusion_matrix(y_test,predict_dc))
print('\n')
print(classification_report(y_test,predict_dc))
# Out:
# 1.0
#
#
# [[1304    0]
#  [   0 1134]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1304
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438
